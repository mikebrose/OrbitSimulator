# %% [markdown]
# # Exploring Earth's Orbit with Euler, Runge-Kutta, and Verlet algorithms
# ## Michael Rose
# ------------------
# The purpose of this notebook is to simulate earth's orbit around the sun and explore a few algorithms to approximate
# solutions of differential equations. We will then modify some initial values and check to see if Kepler's laws hold in the simulation

# %% [markdown]
# ![Image](https://www.scienceabc.com/wp-content/uploads/2018/08/earth_sun___moon.jpg)

# %% [markdown]
# Neglecting the gravitational influences from other planets. The force on earth due to gravity is
# $$F = -\frac{Gm_1m_2}{r^2}\hat{r}$$
# unit vector $\hat{r}$ points from the sun towards the earth. The magnitude of potential energy due to gravity is:
# $$U = -\frac{Gm_1m_2}{r} $$
# The negative value might confuse some, but energy is defined such that $U$ approaches 0 as $r$ approaches $\infty$
#
# Convenient units in this case will be:
# Au: Astronomical Unit = Average distance between Earth and Sun
# years
# $M_\odot$ Solar Mass = Weight of Sun( sun = 1 sm)
# Newton's 2nd Law tells us that $F=ma$. Our radial acceleration is given by $$a_{rad} = \frac{v^2}{r}$$
# Since the earth completes (roughly) 1 orbit in 1 year, we know that tangential velocity is about:
# $$v = \frac{2\pi r}{\omega} = 2\pi(1)  Au*yr^{-1}$$
# then: $$\frac{m_ev^2}{r}=\frac{Gm_sm_e}{r^2}$$
# We can solve this for G: $$ G = \frac{4\pi^2}{m_s} (Au^3M_\odot^-1yr^-2)$$
#
# Finally, now that we have a value for G in convenient units, we can account for force in both the x and y components.
# Setting the sun at our origin:
# $$ F_x=-\frac{Gm_sm_e}{r^3}x\hat{x}\enspace and\enspace F_y=-\frac{Gm_sm_e}{r^3}y\hat{y} $$
# $$ \:a_x=-\frac{Gm_s}{r^3}x\hat{x}\enspace and \enspace a_y=-\frac{Gm_s}{r^3}y\hat{y} $$

# %% [markdown]
# ### Setting up some initial values

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import plotly.express as px

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
import plotly.graph_objects as go
# For offline use
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Sanity check for G in Si units
Au = 1.496e+11 #meters
yr = 3.154e+7 #seconds
Sm = 1.989e+30 #solar mass in Kg
sunrad = 0.00465047 # in Au
# G amount check
print('G in SI: ', 4*np.pi**2*Au**3/(yr**2*Sm))
# Out:
# G in SI:  6.680305997591103e-11

# %%
G = 4*np.pi**2 # Au^3*MS^-1*yr^-2

# %%
#setting initial conditions with perihelion at y=0 and vy0 in y direction

Me = 1/(332946) # earth in Solar Masses
Ms = 1 # Sun in solar Masses
x0 = 0.9832899 #Au perihelion using official observations for initial conditions
y0 = 0
vx0 = 0
vy0 = 30.29/1.496e+8*3.154e+7 #again official obs for v at perihelion

# %%
# initial values
x=x0
y=y0
vx= vx0
vy= vy0

xpos = np.array([x0])
ypos = np.array([y0])
xvels = np.array([vx0])
yvels = np.array([vy0])
TotalE = np.array([])

# %% [markdown]
# ## Euler Method
# To approximate each step we use:
# $$ x_{i+1} = x_i + \frac{dx}{dt}\Delta t $$

# %%
dt=.01
for i in np.linspace(0,1,101):
    r = np.sqrt(x**2+y**2)
    ax = -G*Ms*x/r**3
    ay = -G*Ms*y/r**3
    #calc next position and next vel
    x = x + vx*dt
    y = y + vy*dt
    vx = vx + ax*dt
    vy = vy + ay*dt
    xpos = np.append(xpos,x)
    ypos = np.append(ypos,y)
    TotalE = np.append(TotalE,.5*Me*(vx**2+vy**2)-G*Me*Ms/r)

# %% [markdown]
# ### Size of the sun is enlarged for visibility

# %%
figure = plt.figure()
axes1 = figure.add_axes([0,0,1,1])
axes1.plot(xpos,ypos)
axes1.set(title='An incomplete simulation',xlabel='X',ylabel='Y')
axes1.axis('equal')
circle1 = plt.Circle((0, 0), .08, color='orange')
axes1.add_artist(circle1)

# %% [markdown]
# Checking the Total Energy to see if believable:
# $$ Total Energy = KineticE + PotentialE $$
# $$ E_{tot} = \frac{1}{2}m_ev^2 + \frac{-Gm_sm_e}{r} $$

# %%
figure2 = plt.figure()
axes2 = figure2.add_axes([0,0,1,1])
axes2.plot(np.linspace(0,1,101),TotalE)
axes2.set(title='Total Energy Change',xlabel='Years',ylabel='Energy    SolarMass*Au^2*yr^-2')
print('Energy Change: ',TotalE.max()-TotalE.min())
# Out:
# Energy Change:  2.0226986453606428e-05

# %% [markdown]
# This is obviously is a problem. We did not complete an orbit in a year, our orbit is expanding, and total energy was not conserved.
# This is due to innaccuracies in the Euler method. A partial remedy is to decrease step size.
# We will decrease dt to .oo1 years and allow it go 3 years this time.

# %%
x=x0
y=y0
vx= vx0
vy= vy0

xpos = np.array([x0])
ypos = np.array([y0])
xvels = np.array([vx0])
yvels = np.array([vy0])
TotalE = np.array([])

dt=.001
for i in np.linspace(0,1,3001):
    r = np.sqrt(x**2+y**2)
    ax = -G*Ms*x/r**3
    ay = -G*Ms*y/r**3
    #calc next position and next vel
    x = x + vx*dt
    y = y + vy*dt
    vx = vx + ax*dt
    vy = vy + ay*dt
    xpos = np.append(xpos,x)
    ypos = np.append(ypos,y)
    TotalE = np.append(TotalE,.5*Me*(vx**2+vy**2)-G*Me*Ms/r)

# %%
df1 = pd.DataFrame({"X":xpos[:-1],"Y":ypos[:-1],'Time':np.linspace(0,3,3001),'Earth':'Earth',
                    "Rad":2,'Color':'Green'})

# %%
import plotly.graph_objects as go
fig = go.Figure(data=[go.Scatter(x=xpos, y=ypos)],layout=go.Layout(
                title=go.layout.Title(text="3 years, dt=.001, Still Inaccurate"),
                width=550,height=550))
fig.update_xaxes(range=[-1.4, 1.4])
fig.update_yaxes(range=[-1.4, 1.4])
fig.update_layout(xaxis_title="x",yaxis_title="y",shapes=[dict(type="circle",xref="x",
                  yref="y",fillcolor="Orange",x0=-.04,y0=-.04,x1=.04,y1=.04,
                  line_color="Orange",),])
fig.show()
# Out:
# <div>
#
#
#             <div id="03aa699c-4d22-4668-ace1-116d93dac9a0" class="plotly-graph-div" style="height:550px; width:550px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById
 0.49390585633184747, 0.4884519476913359, 0.48297830609946585, 0.47748515744504955, 0.4719727282585831, 0.4664412457009584, 0.46089093755216404, 0.45532203219997663, 0.4497347586286433, 0.44412934640755625, 0.43850602567991953, 0.4328650271514103, 0.42720658207883355, 0.4215309222587727, 0.415838280016236, 0.41012888819329957, 0.40440298013774834, 0.39866078969171537, 0.3929025511803202, 0.38712849940030747, 0.3813388696086862, 0.37553389751137073, 0.369713819251824, 0.36387887139970404, 0.3580292909395143, 0.35216531525925876, 0.3462871821391025, 0.34039512974003844, 0.3344893965925614, 0.3285702215853492, 0.3226378439539532, 0.3166925032694971, 0.3107344394273867, 0.3047638926360295, 0.2987811034055664, 0.292786 ...

# %%
figure2 = plt.figure()
axes2 = figure2.add_axes([0,0,1,1])
axes2.plot(np.linspace(0,3,3001),TotalE)
axes2.set(title='Total Energy Change: S',xlabel='Years',ylabel='Energy    SolarMass*Au^2*yr^-2')
print('Energy Change: ',TotalE.max()-TotalE.min())
# Out:
# Energy Change:  9.757284920771528e-06

# %% [markdown]
# We still see an increase in Total Energy although not as severe. After decreasing our step size
# by a factor of 10 we see only a modest effect on Total Energy inflation

# %% [markdown]
# --------------------
# ## 2nd Order Runge-Kutta
# This is a much more accurate method, we should be able to lengthen our step size and still expect more accuracy.
# We could opt for 4th order but this should be accurate enough.
# $$ \mathit{f}=\frac{dx}{dt}$$
# $$ x_{i+1} =x_i + h(\frac{1}{2}k_1+\frac{1}{2}k_2)$$ $$where$$ $$k_1 =\mathit{f}(t_i,x_i)$$
# $$k_2=\mathit{f}(t_i+h,x_i+k_1h)$$
# This is essentially saying: "Using known accel and vel at pos $x_i$, estimate what position and vel will be
# at the next $\frac{1}{2}\Delta t$
# Then calculate average accel at $\frac{1}{2}\Delta t$, then use those "intermediate" accel,vel values over the whole interval $\Delta t$ to find a more accurate x position"

# %%
x=x0
y=y0
vx= vx0
vy= vy0
xpos = np.array([x0])
ypos = np.array([y0])
xvels = np.array([vx0])
yvels = np.array([vy0])
TotalE = np.array([])
dt = .01
for i in np.linspace(0,1,101):
    r = np.sqrt(x**2+y**2)
    TotalE = np.append(TotalE,.5*Me*(vx**2+vy**2)-G*Me*Ms/r)
    ax = -G*Ms*x/r**3
    ay = -G*Ms*y/r**3
    #estimates halfway across dt
    xmid = x+vx*.5*dt
    vxmid = vx+ax*.5*dt
    ymid = y+vy*.5*dt
    vymid = vy+ay*.5*dt
    axmid = -G*Ms*xmid/(xmid**2+ymid**2)**(3/2)
    aymid = -G*Ms*ymid/(xmid**2+ymid**2)**(3/2)
    #full Euler Step
    xnew  =  x + vxmid*dt
    ynew  =  y + vymid*dt
    vxnew = vx + axmid*dt
    vynew = vy + aymid*dt

    xpos = np.append(xpos,xnew)
    ypos = np.append(ypos,ynew)
    xvels = np.append(xvels,vxnew)
    yvels = np.append(yvels,vxnew)
        
    #set new as old
    x,y,vx,vy = xnew,ynew,vxnew,vynew

# %%
fig = go.Figure(data=[go.Scatter(x=xpos, y=ypos)],layout=go.Layout(
834563309087025, 0.911360097189246, 0.9355958577490788, 0.9560775094954934, 0.9727347806652809, 0.9855133323971029, 0.9943747855983931, 0.999296676265095, 1.0002723427528273, 0.9973107487656211, 0.9904362460254553, 0.9796882807157777, 0.9651210478593604, 0.9468030978002531, 0.924816898916865, 0.8992583606042948, 0.8702363204351082, 0.8378719992450524, 0.8022984276998347, 0.7636598476870444, 0.7221110916492414, 0.6778169427355301, 0.630951478404547, 0.5816973998662677, 0.5302453495075106, 0.47679321821017434, 0.4215454442453555, 0.36471230521342485, 0.30650920430236495, 0.24715595195630566, 0.1868760438850311, 0.12589593620475392, 0.06444431838187702, 0.002751384555758192, -0.0589518962555955, -0.12043451061090502, -0.18146613132948264, -0.24181784796971523, -0.30126289664232414, -0.35957738864804945, -0.4165410373547171, -0.47193788263031233, -0.5255570120274472, -0.577193277771443, -0.6266480084403744, -0.673729714042333, -0.7182547829946814, -0.7600481692943125, -0.7989440679394245, -0.8347865764249618, -0.8674303398889703, -0.8967411772394206, -0.9225966853447373, -0.944886818130961, -0.9635144371991831, -0.9783958303640524, -0.9894611943235119, -0.996655077507489, -0.9999367790252518, -0.9992806995437905, -0.9946766398891255, -0.9861300431748296, -0.9736621763329173, -0.9573102470566064, -0.93712745236658, -0.9131829552855694, -0.8855617864524752, -0.8543646679276446, -0.8197077569345749, -0.7817223078478248, -0.7405542513681045, -0.696363690517354, -0.6493243138312703, -0.5996227 ...
#                         {"height": 550, "shapes": [{"fillcolor": "Orange", "line": {"color": "Orange"}, "type": "circle", "x0": -0.04, "x1": 0.04, "xref": "x", "y0": -0.04, "y1": 0.04, "yref": "y"}], "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}],

# %%
figure3 = plt.figure()
axes3 = figure3.add_axes([0,0,1,1])
axes3.plot(np.linspace(0,1,101),TotalE)
TotalE.max()-TotalE.min()
axes3.set(title='RK2 Total Energy Change',xlabel='Time',ylabel='Energy SolarMass*Au^2*yr^-2')
# Out:
# [Text(0, 0.5, 'Energy SolarMass*Au^2*yr^-2'),
#  Text(0.5, 0, 'Time'),
#  Text(0.5, 1.0, 'RK2 Total Energy Change')]

# %%
# Energy Gain RK2  over Energy Gain Euler Δt = .05
1.2225685934532683e-08/2.0226986453606428e-05
# Out:
# 0.0006044244881744542

# %% [markdown]
# Our False energy gain is now less than 1/1000 of what we started with and is close to 0

# %% [markdown]
# Much Better, Check over a time period of 10 years to look for false Total Energy inflation

# %%
x=x0
y=y0
vx= vx0
vy= vy0
xpos = np.array([x0])
ypos = np.array([y0])
xvels = np.array([vx0])
yvels = np.array([vy0])
TotalE = np.array([])
dt = .01
for i in np.linspace(0,10,1001):
    r = np.sqrt(x**2+y**2)
    TotalE = np.append(TotalE,.5*Me*(vx**2+vy**2)-G*Me*Ms/r)
    ax = -G*Ms*x/r**3
    ay = -G*Ms*y/r**3
    #estimates halfway across dt
    xmid = x+vx*.5*dt
    vxmid = vx+ax*.5*dt
    ymid = y+vy*.5*dt
    vymid = vy+ay*.5*dt
    axmid = -G*Ms*xmid/(xmid**2+ymid**2)**(3/2)
    aymid = -G*Ms*ymid/(xmid**2+ymid**2)**(3/2)
    #full Euler Step
    xnew  =  x + vxmid*dt
    ynew  =  y + vymid*dt
    vxnew = vx + axmid*dt
    vynew = vy + aymid*dt

    xpos = np.append(xpos,xnew)
    ypos = np.append(ypos,ynew)
    xvels = np.append(xvels,vxnew)
    yvels = np.append(yvels,vxnew)
        
    #set new as old
    x,y,vx,vy = xnew,ynew,vxnew,vynew

# %%
fig = go.Figure(data=[go.Scatter(x=xpos, y=ypos)],layout=go.Layout(
                title=go.layout.Title(text="Runge-Kutta Method   10 Years"),
                width=550,height=550))
fig.update_xaxes(range=[-1.2, 1.2])
fig.update_yaxes(range=[-1.2, 1.2])
fig.update_layout(xaxis_title="x",yaxis_title="y",shapes=[dict(type="circle",xref="x",
                  yref="y",fillcolor="Orange",x0=-.04,y0=-.04,x1=.04,y1=.04,
                  line_color="Orange",),])
print('Zoom in on path to see consistency')
fig.show()
# Out:
# Zoom in on path to see consistency
# <div>
#
#
#             <div id="e2f9ddf5-59a2-4aff-837d-b9271cf3d36c" class="plotly-graph-div" style="height:550px; width:550px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e2f9ddf5-59a2-4aff-837d-b9271cf3d36c")) {
#                     Plotly.newPlot(
#                         'e2f9ddf5-59a2-4aff-837d-b9271cf3d36c',
#                         [{"type": "scatter", "x": [0.9832899, 0.9812483191446811, 0.9751344781801469, 0.9649750390048316, 0.9508142806575164, 0.9327138511990862, 0.9107524235317882, 0.8850252584554215, 0.8556436791058388, 0.8227344616952107, 0.7864391481637295, 0.7469132869490825, 0.7043256085757497, 0.658857143156177, 0.6107002871778547, 0.5600578271244697, 0.5071419275481365, 0.45217309117787774, 0.39537909852354525, 0.33699393422233626, 0.2772567070863113, 0.21641057045411372, 0.15470164903928205, 0.09237797801224235, 0.029688459564366734, -0.0331181583088203, -0.09579427659182362, -0.1580944099136353, -0.2197761179257102, -0.28060090073327665, -0.3403350562058397, -0.39875049745252955, -0.45562552917683696, -0.5107455820196243, -0.5639039043564306, -0.6149022113332389, -0.6635512912030957, -0.7096715692640583, -0.7530936298973225, -0.7936586973640494, -0.8312190761417868, -0.8656385516683225, -0.8967927524144053, -0.9245694742294054, -0.9488689678981564, -0.969604190815581, -0.9867010236309565, -1.000098452638573, -1.0097487185988496, -1.0156174325664522, -1.0176836591823641, -1.0159399677579033, -1.0103924513430826, -1.0010607138321532, -0.987977825018335, -0.9711902433703057, -0.9507577061676733, -0.9267530865040899, -0.8992622165476091, -0.868383676341073, -0.8342285473335219, -0.796920129759612, -0.7565936229306209, -0.7133957674705618, -0.6674844485269769, -0.6190282590107822, -0.5682060219756345, -0.515206271337053, -0.46022669025708485, -0.4034735066834748, -0.34516084573452327, -0.28551003886305903, -0.22474889001561016, -0.1631108993256758, -0.10083444524197863, -0.03816192639187206, 0.024661135086067335, 0.08738702654155144, 0.14976681145475101, 0.21155132652071754, 0.27249220545134145, 0.3323429252403847, 0.39085987011079326, 0.44780340785027756, 0.5029389727514352, 0.5560381489173664, 0.6068797472839579, 0.6552508693569333, 0.7009479503762414, 0.7437777744126095, 0.7835584537804036, 0.8201203651252823, 0.8533070346209092, 0.8829759648906352, 0.9089993965599238, 0.9312649977432955, 0.9496764752732111, 0.9641541020824962, 0.9746351558490745, 0.9810742647919187, 0.9834436573580908, 0.9817333134484267, 0.9759510157782074, 0.9661223009422597, 0.9522903107339282, 0.9345155452366188, 0.9128755201478418, 0.8874643316923642, 0.8583921333179698, 0.8257845291308071, 0.7897818897057687, 0.7505385964914214, 0.7082222215117465, 0.6630126494439298, 0.615101149420758, 0.5646894040683611, 0.5119885033479306, 0.45721791072853885, 0.4006044090840265, 0.3423810334883345, 0.2827859977900895, 0.2220616214889813, 0.16045326302433469, 0.09820826513132273, 0.03557491743346623, -0.02719855906791982, -0.08986500146573026, -0.1521792647596563, -0.2138991489023644, -0.27478629047171793, -0.33460701683993216, -0.39313316116246916, -0.45014283693038226, -0.505421171216223, -0.5587609960929903, -0.6099634980162804, -0.6588388252309225, -0.7052066534948367, -0.7488967106050848, -0.7897492603651423, -0.8276155467497406, -0.8623581991060454, -0.8938515992795604, -0.9219822115723009, -0.9466488764319615, -0.9677630687366146, -0.9852491214825817, -0.9990444156062455, -1.0090995365764253, -1.0153783982852616, -1.0178583346450472, -1.016530159168809, -1.011398192676357, -1.0024802591276625, -0.9898076494444517, -0.9734250530415023, -0.9533904566539676, -0.9297750099188534, -0.9026628570502611, -0.8721509338419453, -0.8383487291399196, -0.8013780098550761, -0.7613725085339, -0.7184775724771575, -0.6728497733946837, -0.6246564766117998, -0.5740753689019968, -0.5212939441137412, -0.46650894588872793, -0.4099257669364551, -0.3517578045370572, -0.2922257721918573, -0.23155696762944417, -0.16998449770394655, -0.10774646109049228, -0.045085090088672744, 0.017754146714670363, 0.08052347870072353, 0.1429738016722426, 0.2048556772684463, 0.2659203595743678, 0.32592084462297694, 0.3846129379578015, 0.441756334907255, 0.49711570772994584, 0.5504617933339123, 0.6015724748632417, 0.6502338500940981, 0.6962412792996782, 0.7394004050402326, 0.779528136219234, 0.816 ...

# %% [markdown]
# Zooming in on the far right side, we can see how closely the orbital paths follow each other

# %%
figure = plt.figure()
axes1 = figure.add_axes([0,0,1,1])
axes1.plot(xpos,ypos,linewidth=1)
axes1.set_xlim([.97,.99])
axes1.set_ylim([-.075,.075])
# Out:
# (-0.075, 0.075)

# %% [markdown]
# -----------------
# ## Verlet Algorithm
# Even more accurate than Runge-Kutta 2nd Order
# This takes the form of common kinematics position function

# %% [markdown]
# (1)$$ x_{mid} = x_{ini} + v_{mid}\Delta t  $$
# (2)$$ v_{mid} = v_{ini} + \frac{1}{2}a_{ini}\Delta t $$
# Substituting (2) into (1):
# $$ x_{fin} = x_{ini} + (v_{ini} + \frac{1}{2}a_{ini}\Delta t)\Delta t$$
# or:
# $$ x_{fin} = x_{ini} + v_{ini}\Delta t + \frac{1}{2}a_{ini}\Delta t^2$$
#
# New velocity at end of interval calculated from average acceleration.
# Accel at end of interval is determined from the new position
# $$ v_{fin} = \frac{a_{ini}+a_{fin}}{2}\Delta t $$

# %%
#defining as function, I will use this a couple times
def verletOrbit(x0,y0,vx0,vy0,dt=.01,tperiod=10):
    x=x0
    y=y0
    vx= vx0 
    vy= vy0 
    xpos = np.array([x0])
    ypos = np.array([y0])
    xvels = np.array([vx0])
    yvels = np.array([vy0])
    TotalE = np.array([])
    r = np.sqrt(x**2+y**2)
    ax = -G*Ms*x/r**3
    ay = -G*Ms*y/r**3
    time = np.array([])
    for i in np.linspace(0,tperiod,int(tperiod/dt)+1):
        time = np.append(time, i)
        r = np.sqrt(x**2+y**2)
        TotalE = np.append(TotalE,.5*Me*(vx**2+vy**2)-G*Me*Ms/r)


        #Now using Verlet
        xnew = x + vx*dt + .5*ax*dt**2
        ynew = y + vy*dt + .5*ay*dt**2
        xpos = np.append(xpos,xnew)
        ypos = np.append(ypos,ynew)
        #Acceleration final
        rnew = np.sqrt(xnew**2+ynew**2)
        axnew= -G*Ms*xnew/rnew**3
        aynew = -G*Ms*ynew/rnew**3 
        #Velocity final
        vxnew = vx + .5*(ax+axnew)*dt
        vynew = vy + .5*(ay+aynew)*dt

        #set new as old
        x,y,vx,vy,ax,ay = xnew,ynew,vxnew,vynew,axnew,aynew
    return xpos,ypos,TotalE,time

# %%
xpos,ypos,TotalE,time = verletOrbit(x0,y0,vx0,vy0,dt=.01,tperiod=10)

# %%
fig = go.Figure(data=[go.Scatter(x=xpos, y=ypos)],layout=go.Layout(
                title=go.layout.Title(text="Verlet Algorithm, 10 years"),
                width=550,height=550))
fig.update_xaxes(range=[-1.2, 1.2])
fig.update_yaxes(range=[-1.2, 1.2])
fig.update_layout(xaxis_title="x",yaxis_title="y",shapes=[dict(type="circle",xref="x",
                  yref="y",fillcolor="Orange",x0=-.04,y0=-.04,x1=.04,y1=.04,
                  line_color="Orange",),])
print('Even closer path consistency, zoom in on path')
fig.show()
print("Perihelion at: ", abs(xpos.min()), 'Au')
print('Aphelion at: ',xpos.max(), 'Au')
# Out:
# Even closer path consistency, zoom in on path
# <div>
#
#
#             <div id="abf618ae-b892-4ebd-8634-fa39ca46a2bb" class="plotly-graph-div" style="height:550px; width:550px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("abf618ae-b892-4ebd-8634-fa39ca46a2bb")) {
#                     Plotly.newPlot(
#                         'abf618ae-b892-4ebd-8634-fa39ca46a2bb',
#                         [{"type": "scatter", "x": [0.9832899, 0.9812483191446811, 0.9751324800310414, 0.9649690432305539, 0.950802277555914, 0.932693813517693, 0.9107223014660564, 0.8849829776503556, 0.8555871422557986, 0.8226615542335142, 0.7863477484166571, 0.7468012810013528, 0.7041909099601514, 0.6586977173425137, 0.6105141806993871, 0.5598432010471774, 0.5068970948626518, 0.45189655757882663, 0.39506960593879736, 0.3366505063673842, 0.27687869624824074, 0.21599770465645554, 0.1542540787040079, 0.09189632121836573, 0.02917384500367843, -0.03366405156016821, -0.0963691833329548, -0.15869544790799087, -0.2203997625556964, -0.2812429658833644, -0.34099068195404747, -0.39941414505959816, -0.45629098376591126, -0.5114059632386748, -0.5645516852126767, -0.6155292452850488, -0.664148847491689
, 0.7036169930813565, 0.6580910582922952, 0.6098779675547827, 0.5591807180072808, 0.506211696709701, 0.45119164457096944, 0.3943485994270252, 0.33591682540472306, 0.27613573543131126, 0.2152488134087299, 0.15350254217726267, 0.09114534295471738, 0.02842653146591859, -0.0344047045167581, -0.09710030200791164, -0.15941429031516757, -0.22110372601867898, -0.2819295927189933, -0.3416576633221474, -0.4000593230801538, -0.45691235202509833, -0.5120016658222626, -0.5651200144193095, -0.6160686381828124, -0.6646578814892253, -0.7107077639744713, -0.7540485098449836, -0.7945210358141165, -0.8319773983526755, -0.8662812010325852, -0.8973079628004226, -0.9249454480449261, -0.9490939593220724, -0.9696665935754283, -0.9865894626408748, -0.9998018787561515, -1.0092565057096856, -1.0149194761625873, -1.0167704755652107, -1.0148027929680332, -1.0090233388984537, -0.9994526303431783, -0.9861247427427956, -0.9690872287736456, -0.9484010035648233, -0.9241401958778397, -0.896391964665795, -0.8652562803306231, -0.8308456699137937, -0.793284925390542, -0.7527107741929818, -0.709271511066047, -0.6631265903647456, -0.6144461779342686, -0.5634106617784751, -0.5102101208194174, -0.4550437511828418, -0.39811924961366457, -0.33965215383253056, -0.2798651398904905, -0.21898727686380168, -0.15725323955441503, -0.09490248022269153, -0.03217836077528736, 0.030672752739918506, 0.09340243102234735, 0.15576115499967533, 0.21749931861063976, 0.27836825708833457, 0.33812129642841265, 0.39651481921762566, 0.45330934150381674, 0.5082705949189029, 0.5611706078320327, 0.6117887789216918, 0.6599129362236975, 0.7053403744470961, 0.7478788631616291, 0.7873476183573789, 0. ...

# %%
figure3 = plt.figure()
axes3 = figure3.add_axes([0,0,1,1])
axes3.plot(TotalE)
axes3.set(title='Verlet Total Energy Change',xlabel='Time',ylabel='Energy SolarMass*Au^2*yr^-2')
print(' Verlet Total Energy variations: ',TotalE.max()-TotalE.min())
# Out:
#  Verlet Total Energy variations:  3.924987734397242e-09

# %% [markdown]
# Extremely Small changes in Total Energy Over 10 Years

# %% [markdown]
# -----------------------------------------------------------------------
# ## Examining Kepler's laws
#
# ![Image](https://www.emedicalprep.com/wp-content/uploads/2-the-first-law-statement.png)
#
# ### Kepler's 1st Law
# The planets follow orbits are that elliptical, with one focus being at the sun
# In an ellipse, the sum of the distance from the foci to a single point on the ellipse
# is the same no matter what point is chosen.
# We will pick 3 to test this.

# %%
xpos,ypos,TotalE,time = verletOrbit(x0,y0,vx0,1.2*vy0,dt=.001,tperiod=10) #changing vy0 to increase eccentricity
df = pd.DataFrame({'X':xpos[:-1],'Y':ypos[:-1],"Time":time})
#picking three time points arbitrarily 
tp1 = df.iloc[50]
tp2 = df.iloc[333]
tp3 = df.iloc[1700]
# 1 Focus is at origin, calculate other
f1 = (0,0)
s = (xpos.max()-xpos.min())/2
f2 = (-2*(s-xpos.max()),0)

# %%
figure = plt.figure()
axes1 = figure.add_axes([0,0,1,1])
axes1.plot(xpos,ypos,linewidth=1)
axes1.set_xlim([-1.2,1.2])
axes1.set_ylim([-1.2,1.2])
axes1.plot([xpos.max(),xpos.min()],[0,0],'C0--',alpha=.5)
axes1.axis('equal')
#tp1
axes1.plot([0,tp1['X']],[0,tp1['Y']],'C02',[f2[0],tp1['X']],[f2[1],tp1['Y']],'C02')
#tp2
axes1.plot([0,tp2['X']],[0,tp2['Y']],'C03',[f2[0],tp2['X']],[f2[1],tp2['Y']],'C03')
#tp3
axes1.plot([0,tp3['X']],[0,tp3['Y']],'C04',[f2[0],tp3['X']],[f2[1],tp3['Y']],'C04')

circle1 = plt.Circle((0, 0), .08, color='orange')
axes1.add_artist(circle1)

# %%
#Calculate and compare distances
# tp1
tp1Dist1=np.linalg.norm([0-tp1[0],0-tp1[1]])
tp1Dist2=np.linalg.norm([f2[0]-tp1[0],f2[1]-tp1[1]])
tp1Dist= tp1Dist1 + tp1Dist2
#tp2
tp2Dist1=np.linalg.norm([0-tp2[0],0-tp2[1]])
tp2Dist2=np.linalg.norm([f2[0]-tp2[0],f2[1]-tp2[1]])
tp2Dist= tp2Dist1 + tp2Dist2
#tp3
tp3Dist1=np.linalg.norm([0-tp3[0],0-tp3[1]])
tp3Dist2=np.linalg.norm([f2[0]-tp3[0],f2[1]-tp3[1]])
tp3Dist= tp3Dist1 + tp3Dist2
print('Dist First Point: ',tp1Dist)
print('Dist Second Point:',tp2Dist)
print('Dist Third Point: ',tp3Dist)
# Out:
# Dist First Point:  3.6598877810661485
# Dist Second Point: 3.6598932645090683
# Dist Third Point:  3.6598659816563295

# %% [markdown]
# ### Kepler's 2nd Law
# The area swept out by the orbit for a given  Δ𝑡  equals another area of the orbit
# during that same  Δ𝑡
# Adjust intial conditions to exaggerate the eccentricity of earth's orbit

# %%
# should shift ellipse to the left, as if impulse initially during prograde
xpos,ypos,TotalE,time = verletOrbit(x0,y0,vx0,1.1*vy0,dt=.001,tperiod=10)

# %%
figure = plt.figure()
axes1 = figure.add_axes([0,0,1,1])
axes1.plot(xpos,ypos,linewidth=1)
axes1.set_xlim([-1.2,1.2])
axes1.set_ylim([-1.2,1.2])
axes1.axis('equal')
line1 = axes1.plot([0,xpos[100]],[0,ypos[100]],color='grey')
line2 = axes1.plot([0,xpos[821]],[0,ypos[821]],color='grey')
axes1.fill_between(xpos[0:101], 0, ypos[:101],color='grey')
axes1.fill_between([0,xpos[100]], 0, [0,ypos[100]],color="grey")
#bottom

axes1.fill_between([0,xpos[821]],[0,ypos[821]],0,color='grey')
axes1.fill_between(xpos[720:821],ypos[720:821],0,color="grey")
circle1 = plt.Circle((0, 0), .08, color='orange')
axes1.add_artist(circle1)

# %% [markdown]
# Picking Time interval 0 to .1, and .72 to .820
# time = .72 roughly at aphelion
# Since dt is small, using Herons formula and summing all triangles within region1
# and region2 can approximate the areas, although this will be an underestimate
#
# Heron's formula:
# $$ Area = \sqrt{p(p-a)(p-b)(p-c)} $$
# $$ p = \frac{a+b+c}{2} $$

# %%
df = pd.DataFrame({'X':xpos[:-1],'Y':ypos[:-1],"Time":time})

# %%
slice1 = df.iloc[0:101]
slice2 = df.iloc[720:821]
area1 = 0
area2 = 0
for i in range(0,len(slice1)-1):
    x0,y0,x1,y1 = slice1.iloc[i][0],slice1.iloc[i][1],slice1.iloc[i+1][0],slice1.iloc[i+1][1]
    a=np.sqrt(x0**2+y0**2)
    b=np.sqrt(x1**2+y1**2)
    c=np.sqrt((x1-x0)**2+(y1-y0)**2)
    p = (a+b+c)/2
    area1 += np.sqrt(p*(p-a)*(p-b)*(p-c))
    
    #redefining these vars for slice2
    x0,y0,x1,y1 = slice2.iloc[i][0],slice2.iloc[i][1],slice2.iloc[i+1][0],slice2.iloc[i+1][1]
    a=np.sqrt(x0**2+y0**2)
    b=np.sqrt(x1**2+y1**2)
    c=np.sqrt((x1-x0)**2+(y1-y0)**2)
    p = (a+b+c)/2
    area2 += np.sqrt(p*(p-a)*(p-b)*(p-c))
print('Area in region 1: ',area1, 'Au^2', '\nArea in region 2: ',area2, 'Au^2')
# Out:
# Area in region 1:  0.34536127308063946 Au^2
# Area in region 2:  0.34536127308063774 Au^2

# %% [markdown]
# ## Kepler's 3rd Law
# $$ (\frac{T_1}{T_2})^2 =  (\frac{s_1}{s_2})^3  $$
# The square of the ratio of periods two different orbits equals the square of the ratio of their semimajor axes
# Creating two orbits to check:
# Orbit1 semimajor axis on y=0
# Orbit2 semimajor axis on x=0

# %%
#resetting a few initial vals
x0 = 0.9832899 #Au perihelion
y0 = 0
vx0 = 0
# vy0 = 2*np.pi # orbital velocity in au and yr
vy0 = 30.29/1.496e+8*3.154e+7

# %%
xpos1,ypos1,TotalE1,time1 = verletOrbit(x0,y0,vx0,vy0=7,dt=.001,tperiod=10)
xpos2,ypos2,TotalE2,time2 = verletOrbit(0,x0,vx0=-7.5,vy0=0,dt=.001,tperiod=10)

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.plot(xpos1,ypos1,'C0',xpos2,ypos2,'C3')
axes.plot([xpos1.max(),xpos1.min()],[0,0],c ='C0',ls='--',alpha=.5)
axes.plot([0,0],[ypos2.min(),ypos2.max()],c ='C3',ls='--',alpha=.5)
axes.set(title='2 different orbits')
circle1 = plt.Circle((0, 0), .08, color='orange')
axes.add_artist(circle1)
axes.axis('equal')
# Out:
# (-1.6915910925840003,
#  1.6559899945452812,
#  -2.4764846190564196,
#  1.4069069129908596)

# %%
# calculate The orbital period for both orbits
df1 = pd.DataFrame({'X':xpos1[:-1],'Y':ypos1[:-1],"Time":time1})
df2 = pd.DataFrame({'X':xpos2[:-1],'Y':ypos2[:-1],"Time":time2})
# 2*(time when crosses semimajor axis)
T1idx =  2*np.argmax(df1['X'].diff()>0)
T1 = df1['Time'][T1idx]
T2idx = 2*np.argmax(df2['Y'].diff()>0)
T2 = df2['Time'][T2idx]
#calculate semimajor axes
s1= (xpos1.max()-xpos1.min())/2
s2= (ypos2.max()-ypos2.min())/2

# %%
Tratio = (T1/T2)**2
sratio = (s1/s2)**3
print('T_ratio^2: ',Tratio,'\nS_ratio^3: ',sratio)
# Out:
# T_ratio^2:  0.4533522004240586
# S_ratio^3:  0.4536194869772409

# %% [markdown]
# Very close, could have gotten closer with smaller dt, taking the average perihelion and aphelion
